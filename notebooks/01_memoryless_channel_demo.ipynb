# %% [markdown]
# # Memoryless channel demo
# This notebook imports the package; run the smoke configuration first.

# %%
from chronocline.channels import build_memoryless_channel
from chronocline.distributions import gaussian
from chronocline.quantization import UniformQuantizer

build_memoryless_channel([0.,1.], gaussian(), UniformQuantizer(.5))
