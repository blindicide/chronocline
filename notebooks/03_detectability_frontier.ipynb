# %% [markdown]
# # Detectability frontier

# %%
from chronocline.information.divergence import kl_divergence

kl_divergence([.5,.5],[.5,.5])
